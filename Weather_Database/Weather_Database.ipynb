# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-90.000, high=90.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 771

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]       
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                   "Lat": city_lat,
                   "Lng": city_lng,
                   "Max Temp": city_max_temp,
                   "Humidity": city_humidity,
                   "Cloudiness": city_clouds,
                   "Wind Speed": city_wind,
                   "Country": city_country,
                   "Current Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | saldanha
# Processing Record 2 of Set 1 | krasnoselkup
# Processing Record 3 of Set 1 | ponta delgada
# Processing Record 4 of Set 1 | dingle
# Processing Record 5 of Set 1 | sao filipe
# Processing Record 6 of Set 1 | diamantino
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | qaanaaq
# Processing Record 9 of Set 1 | ordubad
# Processing Record 10 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 1 | jibuti
# Processing Record 12 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 1 | jamestown
# Processing Record 14 of Set 1 | vardo
# Processing Record 15 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 1 | hermanus
# Processing Record 17 of Set 1 | taybad
# Processing Record 18 of Set 1 | longyearbyen
# Processing Record 19 of Set 1 | port elizabeth
# Processing Record 20 of Set 1 | busselton
# Processing Record 21 of Set 1 | port alfred
# Processing Record 22 of Set 1 | pisco
# Processing Record 23 of Set 1 | chebsara
# Processing Record 24 of Set 1 | batticaloa
# Processing Record 25 of Set 1 | kuche
# City not found. Skipping...
# Processing Record 26 of Set 1 | itacare
# Processing Record 27 of Set 1 | wattens
# Processing Record 28 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 1 | piacabucu
# Processing Record 30 of Set 1 | kudahuvadhoo
# Processing Record 31 of Set 1 | husavik
# Processing Record 32 of Set 1 | micheweni
# Processing Record 33 of Set 1 | clyde river
# Processing Record 34 of Set 1 | bandarbeyla
# Processing Record 35 of Set 1 | armacao dos buzios
# City not found. Skipping...
# Processing Record 36 of Set 1 | hithadhoo
# Processing Record 37 of Set 1 | mitu
# Processing Record 38 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 1 | ponta do sol
# Processing Record 40 of Set 1 | cape town
# Processing Record 41 of Set 1 | novoagansk
# Processing Record 42 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 1 | knysna
# Processing Record 44 of Set 1 | bambous virieux
# Processing Record 45 of Set 1 | cururupu
# Processing Record 46 of Set 1 | bilma
# Processing Record 47 of Set 1 | zawiercie
# Processing Record 48 of Set 1 | resistencia
# Processing Record 49 of Set 1 | ribeira grande
# Processing Record 50 of Set 1 | najran
# Processing Record 1 of Set 2 | paso de carrasco
# Processing Record 2 of Set 2 | dikson
# Processing Record 3 of Set 2 | kalevala
# Processing Record 4 of Set 2 | sinnamary
# Processing Record 5 of Set 2 | melioratorov
# Processing Record 6 of Set 2 | zyryanovsk
# Processing Record 7 of Set 2 | cesis
# Processing Record 8 of Set 2 | hambantota
# Processing Record 9 of Set 2 | luanda
# Processing Record 10 of Set 2 | itarema
# Processing Record 11 of Set 2 | brae
# Processing Record 12 of Set 2 | bonthe
# Processing Record 13 of Set 2 | bereda
# Processing Record 14 of Set 2 | lebu
# Processing Record 15 of Set 2 | cognac
# Processing Record 16 of Set 2 | bur gabo
# City not found. Skipping...
# Processing Record 17 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 18 of Set 2 | orichi
# Processing Record 19 of Set 2 | harlingen
# Processing Record 20 of Set 2 | aksu
# Processing Record 21 of Set 2 | georgetown
# Processing Record 22 of Set 2 | laguna
# Processing Record 23 of Set 2 | meghri
# Processing Record 24 of Set 2 | beinamar
# Processing Record 25 of Set 2 | bredasdorp
# Processing Record 26 of Set 2 | burica
# City not found. Skipping...
# Processing Record 27 of Set 2 | senneterre
# Processing Record 28 of Set 2 | benguela
# Processing Record 29 of Set 2 | chuy
# Processing Record 30 of Set 2 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 31 of Set 2 | acandi
# Processing Record 32 of Set 2 | souillac
# Processing Record 33 of Set 2 | siemiatycze
# Processing Record 34 of Set 2 | linden
# Processing Record 35 of Set 2 | upernavik
# Processing Record 36 of Set 2 | kavaratti
# Processing Record 37 of Set 2 | east london
# Processing Record 38 of Set 2 | marzuq
# Processing Record 39 of Set 2 | asuncion
# Processing Record 40 of Set 2 | southern pines
# Processing Record 41 of Set 2 | luderitz
# Processing Record 42 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 2 | saint-philippe
# Processing Record 44 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 45 of Set 2 | gravina in puglia
# Processing Record 46 of Set 2 | caravelas
# Processing Record 47 of Set 2 | lokosovo
# Processing Record 48 of Set 2 | akim swedru
# Processing Record 49 of Set 2 | saint-louis
# Processing Record 50 of Set 2 | antofagasta
# Processing Record 1 of Set 3 | maceio
# Processing Record 2 of Set 3 | naantali
# Processing Record 3 of Set 3 | talara
# Processing Record 4 of Set 3 | sabha
# Processing Record 5 of Set 3 | mangan
# Processing Record 6 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 7 of Set 3 | galway
# Processing Record 8 of Set 3 | komatipoort
# Processing Record 9 of Set 3 | bahia blanca
# Processing Record 10 of Set 3 | nouadhibou
# Processing Record 11 of Set 3 | bonavista
# Processing Record 12 of Set 3 | lofthus
# Processing Record 13 of Set 3 | punta arenas
# Processing Record 14 of Set 3 | vallenar
# Processing Record 15 of Set 3 | arraial do cabo
# Processing Record 16 of Set 3 | bhadrachalam
# Processing Record 17 of Set 3 | castelnau-le-lez
# Processing Record 18 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 3 | laukaa
# Processing Record 20 of Set 3 | hofn
# Processing Record 21 of Set 3 | fonte boa
# Processing Record 22 of Set 3 | tricase
# Processing Record 23 of Set 3 | zhezkazgan
# Processing Record 24 of Set 3 | vestmannaeyjar
# Processing Record 25 of Set 3 | mersin
# Processing Record 26 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 27 of Set 3 | victoria
# Processing Record 28 of Set 3 | vila velha
# Processing Record 29 of Set 3 | san andres
# Processing Record 30 of Set 3 | itupiranga
# Processing Record 31 of Set 3 | hetauda
# Processing Record 32 of Set 3 | nantucket
# Processing Record 33 of Set 3 | faya
# Processing Record 34 of Set 3 | lagoa
# Processing Record 35 of Set 3 | ambilobe
# Processing Record 36 of Set 3 | dudinka
# Processing Record 37 of Set 3 | talnakh
# Processing Record 38 of Set 3 | nisporeni
# Processing Record 39 of Set 3 | iranshahr
# Processing Record 40 of Set 3 | san juan
# Processing Record 41 of Set 3 | bondo
# Processing Record 42 of Set 3 | reinosa
# Processing Record 43 of Set 3 | morant bay
# Processing Record 44 of Set 3 | richards bay
# Processing Record 45 of Set 3 | kribi
# Processing Record 46 of Set 3 | awjilah
# Processing Record 47 of Set 3 | ilulissat
# Processing Record 48 of Set 3 | maniitsoq
# Processing Record 49 of Set 3 | orel
# Processing Record 50 of Set 3 | cidreira
# Processing Record 1 of Set 4 | luba
# Processing Record 2 of Set 4 | baherden
# Processing Record 3 of Set 4 | skalistyy
# City not found. Skipping...
# Processing Record 4 of Set 4 | fereydun kenar
# Processing Record 5 of Set 4 | margate
# Processing Record 6 of Set 4 | mahebourg
# Processing Record 7 of Set 4 | cayenne
# Processing Record 8 of Set 4 | sao joao da barra
# Processing Record 9 of Set 4 | axim
# Processing Record 10 of Set 4 | matara
# Processing Record 11 of Set 4 | sorochinsk
# Processing Record 12 of Set 4 | tabulbah
# City not found. Skipping...
# Processing Record 13 of Set 4 | osa
# Processing Record 14 of Set 4 | lima
# Processing Record 15 of Set 4 | nouakchott
# Processing Record 16 of Set 4 | carballo
# Processing Record 17 of Set 4 | arona
# Processing Record 18 of Set 4 | kalmunai
# Processing Record 19 of Set 4 | paamiut
# Processing Record 20 of Set 4 | saint anthony
# Processing Record 21 of Set 4 | jacareacanga
# Processing Record 22 of Set 4 | gidole
# Processing Record 23 of Set 4 | comodoro rivadavia
# Processing Record 24 of Set 4 | neyshabur
# Processing Record 25 of Set 4 | tirlyanskiy
# Processing Record 26 of Set 4 | kasongo-lunda
# Processing Record 27 of Set 4 | mizoch
# Processing Record 28 of Set 4 | adiake
# Processing Record 29 of Set 4 | bozova
# Processing Record 30 of Set 4 | prainha
# Processing Record 31 of Set 4 | svetlyy
# Processing Record 32 of Set 4 | puri
# Processing Record 33 of Set 4 | kruisfontein
# Processing Record 34 of Set 4 | bajil
# Processing Record 35 of Set 4 | derzhavinsk
# Processing Record 36 of Set 4 | saint george
# Processing Record 37 of Set 4 | yelan
# Processing Record 38 of Set 4 | sao felix do xingu
# Processing Record 39 of Set 4 | savannah bight
# Processing Record 40 of Set 4 | susangerd
# Processing Record 41 of Set 4 | tambura
# Processing Record 42 of Set 4 | camocim
# Processing Record 43 of Set 4 | araouane
# Processing Record 44 of Set 4 | budelsdorf
# Processing Record 45 of Set 4 | malanje
# Processing Record 46 of Set 4 | campagna
# Processing Record 47 of Set 4 | gumdag
# Processing Record 48 of Set 4 | ambovombe
# Processing Record 49 of Set 4 | aswan
# Processing Record 50 of Set 4 | akyab
# Processing Record 1 of Set 5 | mar del plata
# Processing Record 2 of Set 5 | general roca
# Processing Record 3 of Set 5 | kerteminde
# Processing Record 4 of Set 5 | inhambane
# Processing Record 5 of Set 5 | coronel oviedo
# Processing Record 6 of Set 5 | kondoa
# Processing Record 7 of Set 5 | camacha
# Processing Record 8 of Set 5 | betafo
# Processing Record 9 of Set 5 | hamilton
# Processing Record 10 of Set 5 | port-de-paix
# City not found. Skipping...
# Processing Record 11 of Set 5 | gudur
# Processing Record 12 of Set 5 | harper
# Processing Record 13 of Set 5 | lebyazhye
# Processing Record 14 of Set 5 | namibe
# Processing Record 15 of Set 5 | owando
# Processing Record 16 of Set 5 | sakakah
# Processing Record 17 of Set 5 | qaqortoq
# Processing Record 18 of Set 5 | ostrovnoy
# Processing Record 19 of Set 5 | port-gentil
# Processing Record 20 of Set 5 | cheuskiny
# City not found. Skipping...
# Processing Record 21 of Set 5 | zamora
# Processing Record 22 of Set 5 | camopi
# Processing Record 23 of Set 5 | marsa matruh
# Processing Record 24 of Set 5 | villamontes
# Processing Record 25 of Set 5 | adrar
# Processing Record 26 of Set 5 | pitimbu
# Processing Record 27 of Set 5 | malwan
# City not found. Skipping...
# Processing Record 28 of Set 5 | vila franca do campo
# Processing Record 29 of Set 5 | xuddur
# Processing Record 30 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 31 of Set 5 | gulshat
# City not found. Skipping...
# Processing Record 32 of Set 5 | thompson
# Processing Record 33 of Set 5 | baghdad
# Processing Record 34 of Set 5 | surovikino
# Processing Record 35 of Set 5 | kilemary
# Processing Record 36 of Set 5 | havoysund
# Processing Record 37 of Set 5 | chicama
# Processing Record 38 of Set 5 | andrushivka
# Processing Record 39 of Set 5 | sorland
# Processing Record 40 of Set 5 | nanortalik
# Processing Record 41 of Set 5 | estelle
# Processing Record 42 of Set 5 | codrington
# Processing Record 43 of Set 5 | sambava
# Processing Record 44 of Set 5 | bridlington
# Processing Record 45 of Set 5 | yanam
# Processing Record 46 of Set 5 | lipari
# Processing Record 47 of Set 5 | sipote
# Processing Record 48 of Set 5 | teya
# Processing Record 49 of Set 5 | zurrieq
# Processing Record 50 of Set 5 | tasiilaq
# Processing Record 1 of Set 6 | morondava
# Processing Record 2 of Set 6 | barra
# Processing Record 3 of Set 6 | praia
# Processing Record 4 of Set 6 | manakara
# Processing Record 5 of Set 6 | gwadar
# Processing Record 6 of Set 6 | sistranda
# Processing Record 7 of Set 6 | boa vista
# Processing Record 8 of Set 6 | yar-sale
# Processing Record 9 of Set 6 | coihaique
# Processing Record 10 of Set 6 | rawson
# Processing Record 11 of Set 6 | mange
# Processing Record 12 of Set 6 | west bay
# Processing Record 13 of Set 6 | cockburn harbour
# City not found. Skipping...
# Processing Record 14 of Set 6 | chake chake
# Processing Record 15 of Set 6 | iqaluit
# Processing Record 16 of Set 6 | sept-iles
# Processing Record 17 of Set 6 | atar
# Processing Record 18 of Set 6 | mamlyutka
# Processing Record 19 of Set 6 | caconda
# Processing Record 20 of Set 6 | rincon
# Processing Record 21 of Set 6 | nizhnevartovsk
# Processing Record 22 of Set 6 | ibresi
# Processing Record 23 of Set 6 | amapa
# Processing Record 24 of Set 6 | gilgit
# Processing Record 25 of Set 6 | quatre cocos
# Processing Record 26 of Set 6 | plettenberg bay
# Processing Record 27 of Set 6 | cumaribo
# City not found. Skipping...
# Processing Record 28 of Set 6 | prokhorovka
# Processing Record 29 of Set 6 | marawi
# Processing Record 30 of Set 6 | crestview
# Processing Record 31 of Set 6 | shakawe
# Processing Record 32 of Set 6 | caete
# Processing Record 33 of Set 6 | santa maria
# Processing Record 34 of Set 6 | senekal
# Processing Record 35 of Set 6 | jiroft
# City not found. Skipping...
# Processing Record 36 of Set 6 | tela
# Processing Record 37 of Set 6 | narsaq
# Processing Record 38 of Set 6 | chibuto
# Processing Record 39 of Set 6 | koslan
# Processing Record 40 of Set 6 | bengkulu
# Processing Record 41 of Set 6 | tatawin
# Processing Record 42 of Set 6 | barcelos
# Processing Record 43 of Set 6 | opuwo
# Processing Record 44 of Set 6 | mananjary
# Processing Record 45 of Set 6 | warmbad
# Processing Record 46 of Set 6 | belsand
# Processing Record 47 of Set 6 | krokeai
# Processing Record 48 of Set 6 | ancud
# Processing Record 49 of Set 6 | matagami
# Processing Record 50 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 1 of Set 7 | grand gaube
# Processing Record 2 of Set 7 | illapel
# Processing Record 3 of Set 7 | buta
# Processing Record 4 of Set 7 | suez
# Processing Record 5 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 6 of Set 7 | scalloway
# City not found. Skipping...
# Processing Record 7 of Set 7 | beyneu
# Processing Record 8 of Set 7 | waw
# Processing Record 9 of Set 7 | cockburn town
# Processing Record 10 of Set 7 | klaksvik
# Processing Record 11 of Set 7 | geraldton
# Processing Record 12 of Set 7 | touros
# Processing Record 13 of Set 7 | soverato
# Processing Record 14 of Set 7 | nikel
# Processing Record 15 of Set 7 | rio brilhante
# Processing Record 16 of Set 7 | mogadishu
# Processing Record 17 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 18 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 19 of Set 7 | taltal
# Processing Record 20 of Set 7 | buraydah
# Processing Record 21 of Set 7 | wahran
# City not found. Skipping...
# Processing Record 22 of Set 7 | rosignol
# Processing Record 23 of Set 7 | abu zabad
# Processing Record 24 of Set 7 | abu dhabi
# Processing Record 25 of Set 7 | hella
# Processing Record 26 of Set 7 | farafangana
# Processing Record 27 of Set 7 | salalah
# Processing Record 28 of Set 7 | carnarvon
# Processing Record 29 of Set 7 | ozinki
# Processing Record 30 of Set 7 | gurupi
# Processing Record 31 of Set 7 | palafrugell
# Processing Record 32 of Set 7 | secunda
# Processing Record 33 of Set 7 | mattru
# Processing Record 34 of Set 7 | castro
# Processing Record 35 of Set 7 | mantua
# Processing Record 36 of Set 7 | sechura
# Processing Record 37 of Set 7 | walkerton
# Processing Record 38 of Set 7 | mahajanga
# Processing Record 39 of Set 7 | san cristobal
# Processing Record 40 of Set 7 | salinas
# Processing Record 41 of Set 7 | sinop
# Processing Record 42 of Set 7 | sehore
# Processing Record 43 of Set 7 | warri
# Processing Record 44 of Set 7 | paragominas
# Processing Record 45 of Set 7 | sumbe
# Processing Record 46 of Set 7 | wallaceburg
# Processing Record 47 of Set 7 | columbus
# Processing Record 48 of Set 7 | vestmanna
# Processing Record 49 of Set 7 | afmadu
# City not found. Skipping...
# Processing Record 50 of Set 7 | leningradskiy
# Processing Record 1 of Set 8 | chapais
# Processing Record 2 of Set 8 | durazno
# Processing Record 3 of Set 8 | andevoranto
# City not found. Skipping...
# Processing Record 4 of Set 8 | olinda
# Processing Record 5 of Set 8 | sawakin
# Processing Record 6 of Set 8 | porto murtinho
# Processing Record 7 of Set 8 | torbay
# Processing Record 8 of Set 8 | padang
# Processing Record 9 of Set 8 | omboue
# Processing Record 10 of Set 8 | inongo
# Processing Record 11 of Set 8 | zachagansk
# City not found. Skipping...
# Processing Record 12 of Set 8 | yenagoa
# Processing Record 13 of Set 8 | nuuk
# Processing Record 14 of Set 8 | hemel hempstead
# Processing Record 15 of Set 8 | vangaindrano
# Processing Record 16 of Set 8 | killybegs
# Processing Record 17 of Set 8 | calbuco
# Processing Record 18 of Set 8 | mikhaylov
# Processing Record 19 of Set 8 | viedma
# Processing Record 20 of Set 8 | la asuncion
# Processing Record 21 of Set 8 | hadejia
# Processing Record 22 of Set 8 | jalu
# Processing Record 23 of Set 8 | esil
# Processing Record 24 of Set 8 | saint-francois
# Processing Record 25 of Set 8 | takoradi
# Processing Record 26 of Set 8 | umtata
# Processing Record 27 of Set 8 | port victoria
# Processing Record 28 of Set 8 | bubaque
# Processing Record 29 of Set 8 | abalak
# Processing Record 30 of Set 8 | mezen
# Processing Record 31 of Set 8 | khash
# Processing Record 32 of Set 8 | zapolyarnyy
# Processing Record 33 of Set 8 | svecha
# Processing Record 34 of Set 8 | belmonte
# Processing Record 35 of Set 8 | sarahan
# Processing Record 36 of Set 8 | rorvik
# Processing Record 37 of Set 8 | rabak
# Processing Record 38 of Set 8 | san carlos
# Processing Record 39 of Set 8 | svetlogorsk
# Processing Record 40 of Set 8 | chupa
# Processing Record 41 of Set 8 | forestville
# Processing Record 42 of Set 8 | orebro
# Processing Record 43 of Set 8 | wamba
# Processing Record 44 of Set 8 | pavlovka
# Processing Record 45 of Set 8 | mbanza-ngungu
# Processing Record 46 of Set 8 | kharan
# Processing Record 47 of Set 8 | ahar
# Processing Record 48 of Set 8 | wajir
# Processing Record 49 of Set 8 | talcahuano
# Processing Record 50 of Set 8 | paracuru
# Processing Record 1 of Set 9 | saint-joseph
# Processing Record 2 of Set 9 | bathsheba
# Processing Record 3 of Set 9 | kralendijk
# Processing Record 4 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 5 of Set 9 | hearst
# Processing Record 6 of Set 9 | tallahassee
# Processing Record 7 of Set 9 | fochville
# Processing Record 8 of Set 9 | grindavik
# Processing Record 9 of Set 9 | tafalla
# Processing Record 10 of Set 9 | oranjemund
# Processing Record 11 of Set 9 | los llanos de aridane
# Processing Record 12 of Set 9 | kochki
# Processing Record 13 of Set 9 | tabory
# Processing Record 14 of Set 9 | chitipa
# Processing Record 15 of Set 9 | bollnas
# Processing Record 16 of Set 9 | puerto carreno
# Processing Record 17 of Set 9 | pokrovskoye
# Processing Record 18 of Set 9 | boca do acre
# Processing Record 19 of Set 9 | ivankiv
# Processing Record 20 of Set 9 | bafoulabe
# Processing Record 21 of Set 9 | skeldon
# Processing Record 22 of Set 9 | brigantine
# Processing Record 23 of Set 9 | coquimbo
# Processing Record 24 of Set 9 | wake forest
# Processing Record 25 of Set 9 | acari
# Processing Record 26 of Set 9 | aleksandrov gay
# Processing Record 27 of Set 9 | tarnogskiy gorodok
# Processing Record 28 of Set 9 | ormara
# Processing Record 29 of Set 9 | batocina
# Processing Record 30 of Set 9 | beruwala
# Processing Record 31 of Set 9 | kisesa
# Processing Record 32 of Set 9 | brasileia
# Processing Record 33 of Set 9 | nurota
# Processing Record 34 of Set 9 | kachiry
# Processing Record 35 of Set 9 | lakselv
# Processing Record 36 of Set 9 | jahrom
# City not found. Skipping...
# Processing Record 37 of Set 9 | saint-augustin
# Processing Record 38 of Set 9 | marrakesh
# Processing Record 39 of Set 9 | ihiala
# Processing Record 40 of Set 9 | thunder bay
# Processing Record 41 of Set 9 | eatonton
# Processing Record 42 of Set 9 | nalut
# Processing Record 43 of Set 9 | bougouni
# Processing Record 44 of Set 9 | plouzane
# Processing Record 45 of Set 9 | sarkand
# Processing Record 46 of Set 9 | goure
# Processing Record 47 of Set 9 | bhag
# Processing Record 48 of Set 9 | warner robins
# Processing Record 49 of Set 9 | cataguases
# Processing Record 50 of Set 9 | sidmouth
# Processing Record 1 of Set 10 | uruzgan
# Processing Record 2 of Set 10 | humboldt
# Processing Record 3 of Set 10 | antalaha
# Processing Record 4 of Set 10 | balkanabat
# Processing Record 5 of Set 10 | kasama
# Processing Record 6 of Set 10 | tselina
# Processing Record 7 of Set 10 | santa cruz de la palma
# Processing Record 8 of Set 10 | independencia
# Processing Record 9 of Set 10 | boden
# Processing Record 10 of Set 10 | nsoko
# Processing Record 11 of Set 10 | gornopravdinsk
# Processing Record 12 of Set 10 | zuwarah
# Processing Record 13 of Set 10 | visakhapatnam
# Processing Record 14 of Set 10 | la sarre
# Processing Record 15 of Set 10 | tolu
# Processing Record 16 of Set 10 | termoli
# Processing Record 17 of Set 10 | presque isle
# Processing Record 18 of Set 10 | dabra
# Processing Record 19 of Set 10 | agde
# Processing Record 20 of Set 10 | taoudenni
# Processing Record 21 of Set 10 | kungalv
# Processing Record 22 of Set 10 | manaus
# Processing Record 23 of Set 10 | laje
# Processing Record 24 of Set 10 | visnes
# Processing Record 25 of Set 10 | calvinia
# Processing Record 26 of Set 10 | cervo
# Processing Record 27 of Set 10 | weimar
# Processing Record 28 of Set 10 | jaciara
# Processing Record 29 of Set 10 | saint-lo
# Processing Record 30 of Set 10 | lasa
# Processing Record 31 of Set 10 | filingue
# Processing Record 32 of Set 10 | novouzensk
# Processing Record 33 of Set 10 | muros
# Processing Record 34 of Set 10 | isabela
# Processing Record 35 of Set 10 | tamandare
# Processing Record 36 of Set 10 | tessalit
# Processing Record 37 of Set 10 | sabzevar
# Processing Record 38 of Set 10 | lerwick
# Processing Record 39 of Set 10 | cap malheureux
# Processing Record 40 of Set 10 | imbituba
# Processing Record 41 of Set 10 | corpus christi
# Processing Record 42 of Set 10 | pointe michel
# Processing Record 43 of Set 10 | gerash
# Processing Record 44 of Set 10 | lalpur
# Processing Record 45 of Set 10 | pizarro
# Processing Record 46 of Set 10 | darnah
# Processing Record 47 of Set 10 | berlevag
# Processing Record 48 of Set 10 | pinhao
# Processing Record 49 of Set 10 | kjollefjord
# Processing Record 50 of Set 10 | karlskoga
# Processing Record 1 of Set 11 | karasburg
# Processing Record 2 of Set 11 | kpandu
# Processing Record 3 of Set 11 | sibut
# Processing Record 4 of Set 11 | port shepstone
# Processing Record 5 of Set 11 | oyonnax
# Processing Record 6 of Set 11 | sinjar
# Processing Record 7 of Set 11 | saint-pierre
# Processing Record 8 of Set 11 | sandnessjoen
# Processing Record 9 of Set 11 | eyl
# Processing Record 10 of Set 11 | springdale
# Processing Record 11 of Set 11 | sisimiut
# Processing Record 12 of Set 11 | alta gracia
# Processing Record 13 of Set 11 | manta
# Processing Record 14 of Set 11 | reconquista
# Processing Record 15 of Set 11 | nawalgarh
# Processing Record 16 of Set 11 | samandag
# Processing Record 17 of Set 11 | vidra
# Processing Record 18 of Set 11 | riyadh
# Processing Record 19 of Set 11 | yarmouth
# Processing Record 20 of Set 11 | ust-tsilma
# Processing Record 21 of Set 11 | semey
# Processing Record 22 of Set 11 | halifax
# Processing Record 23 of Set 11 | weymouth
# Processing Record 24 of Set 11 | porto torres
# Processing Record 25 of Set 11 | bardiyah
# Processing Record 26 of Set 11 | kedrovyy
# Processing Record 27 of Set 11 | maneromango
# Processing Record 28 of Set 11 | partyzany
# Processing Record 29 of Set 11 | yefira
# City not found. Skipping...
# Processing Record 30 of Set 11 | praia da vitoria
# Processing Record 31 of Set 11 | tabou
# Processing Record 32 of Set 11 | mitsamiouli
# Processing Record 33 of Set 11 | xambioa
# Processing Record 34 of Set 11 | dubna
# Processing Record 35 of Set 11 | bar harbor
# Processing Record 36 of Set 11 | lisakovsk
# Processing Record 37 of Set 11 | itaituba
# Processing Record 38 of Set 11 | oriximina
# Processing Record 39 of Set 11 | belyy yar
# Processing Record 40 of Set 11 | ozgon
# City not found. Skipping...
# Processing Record 41 of Set 11 | nioro
# Processing Record 42 of Set 11 | kambove
# Processing Record 43 of Set 11 | guia de isora
# Processing Record 44 of Set 11 | ribas do rio pardo
# Processing Record 45 of Set 11 | raga
# Processing Record 46 of Set 11 | tharad
# Processing Record 47 of Set 11 | toguchin
# Processing Record 48 of Set 11 | manbij
# Processing Record 49 of Set 11 | santo antonio do sudoeste
# Processing Record 50 of Set 11 | scarborough
# Processing Record 1 of Set 12 | araguari
# Processing Record 2 of Set 12 | san antonio
# Processing Record 3 of Set 12 | eregli
# Processing Record 4 of Set 12 | adamovka
# Processing Record 5 of Set 12 | bakchar
# Processing Record 6 of Set 12 | correntina
# Processing Record 7 of Set 12 | norrtalje
# Processing Record 8 of Set 12 | belle glade
# Processing Record 9 of Set 12 | wanlaweyn
# Processing Record 10 of Set 12 | atasu
# Processing Record 11 of Set 12 | kinshasa
# Processing Record 12 of Set 12 | olean
# Processing Record 13 of Set 12 | san pedro
# Processing Record 14 of Set 12 | kharp
# Processing Record 15 of Set 12 | kidal
# Processing Record 16 of Set 12 | sembe
# Processing Record 17 of Set 12 | neftcala
# Processing Record 18 of Set 12 | mindelo
# Processing Record 19 of Set 12 | mozarlandia
# Processing Record 20 of Set 12 | lubsko
# Processing Record 21 of Set 12 | boddam
# Processing Record 22 of Set 12 | rio gallegos
# Processing Record 23 of Set 12 | villarrica
# Processing Record 24 of Set 12 | dakar
# Processing Record 25 of Set 12 | misratah
# Processing Record 26 of Set 12 | cabedelo
# Processing Record 27 of Set 12 | malumfashi
# Processing Record 28 of Set 12 | snezhnogorsk
# Processing Record 29 of Set 12 | iracoubo
# Processing Record 30 of Set 12 | kangaatsiaq
# Processing Record 31 of Set 12 | formiga
# Processing Record 32 of Set 12 | valadares
# Processing Record 33 of Set 12 | asfi
# Processing Record 34 of Set 12 | shemonaikha
# Processing Record 35 of Set 12 | terrasini
# Processing Record 36 of Set 12 | stornoway
# Processing Record 37 of Set 12 | uusikaupunki
# Processing Record 38 of Set 12 | vila do maio
# Processing Record 39 of Set 12 | bouna
# Processing Record 40 of Set 12 | save
# Processing Record 41 of Set 12 | kamenka
# Processing Record 42 of Set 12 | palasa
# Processing Record 43 of Set 12 | nuwara eliya
# Processing Record 44 of Set 12 | parauna
# Processing Record 45 of Set 12 | nchelenge
# Processing Record 46 of Set 12 | arlit
# Processing Record 47 of Set 12 | port-cartier
# Processing Record 48 of Set 12 | santa cruz
# Processing Record 49 of Set 12 | raudeberg
# Processing Record 50 of Set 12 | poughkeepsie
# Processing Record 1 of Set 13 | westport
# Processing Record 2 of Set 13 | sur
# Processing Record 3 of Set 13 | emba
# Processing Record 4 of Set 13 | longlac
# City not found. Skipping...
# Processing Record 5 of Set 13 | quarai
# Processing Record 6 of Set 13 | lukaya
# Processing Record 7 of Set 13 | tabuk
# Processing Record 8 of Set 13 | usak
# Processing Record 9 of Set 13 | grand baie
# Processing Record 10 of Set 13 | escarcega
# Processing Record 11 of Set 13 | tanout
# Processing Record 12 of Set 13 | oistins
# Processing Record 13 of Set 13 | poco verde
# Processing Record 14 of Set 13 | ciuchici
# Processing Record 15 of Set 13 | boueni
# Processing Record 16 of Set 13 | loandjili
# Processing Record 17 of Set 13 | rensvik
# Processing Record 18 of Set 13 | sao gabriel da cachoeira
# Processing Record 19 of Set 13 | lugovoy
# Processing Record 20 of Set 13 | leshukonskoye
# Processing Record 21 of Set 13 | crepy-en-valois
# Processing Record 22 of Set 13 | chabahar
# Processing Record 23 of Set 13 | shchuchye
# City not found. Skipping...
# Processing Record 24 of Set 13 | kisangani
# Processing Record 25 of Set 13 | pimentel
# Processing Record 26 of Set 13 | troy
# Processing Record 27 of Set 13 | vale da amoreira
# Processing Record 28 of Set 13 | pontes e lacerda
# Processing Record 29 of Set 13 | ajdabiya
# Processing Record 30 of Set 13 | mizdah
# Processing Record 31 of Set 13 | gravdal
# Processing Record 32 of Set 13 | jumla
# Processing Record 33 of Set 13 | shawville
# Processing Record 34 of Set 13 | sidi bu zayd
# City not found. Skipping...
# Processing Record 35 of Set 13 | ferkessedougou
# Processing Record 36 of Set 13 | yangambi
# Processing Record 37 of Set 13 | birao
# Processing Record 38 of Set 13 | bom jardim
# Processing Record 39 of Set 13 | santa isabel do rio negro
# Processing Record 40 of Set 13 | tsienyane
# City not found. Skipping...
# Processing Record 41 of Set 13 | eirunepe
# Processing Record 42 of Set 13 | karaton
# Processing Record 43 of Set 13 | kortkeros
# Processing Record 44 of Set 13 | khokhryaki
# Processing Record 45 of Set 13 | giaveno
# Processing Record 46 of Set 13 | angoche
# Processing Record 47 of Set 13 | piranhas
# Processing Record 48 of Set 13 | maarianhamina
# Processing Record 49 of Set 13 | paita
# Processing Record 50 of Set 13 | umm lajj
# Processing Record 1 of Set 14 | impfondo
# Processing Record 2 of Set 14 | geresk
# City not found. Skipping...
# Processing Record 3 of Set 14 | monforte de lemos
# Processing Record 4 of Set 14 | antonina
# Processing Record 5 of Set 14 | juan lacaze
# Processing Record 6 of Set 14 | usinsk
# Processing Record 7 of Set 14 | oksovskiy
# Processing Record 8 of Set 14 | dubenskiy
# City not found. Skipping...
# Processing Record 9 of Set 14 | sao desiderio
# Processing Record 10 of Set 14 | nagornskiy
# Processing Record 11 of Set 14 | abu jubayhah
# City not found. Skipping...
# Processing Record 12 of Set 14 | unye
# City not found. Skipping...
# Processing Record 13 of Set 14 | necochea
# Processing Record 14 of Set 14 | sidi ali
# Processing Record 15 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 16 of Set 14 | lubango
# Processing Record 17 of Set 14 | giyani
# Processing Record 18 of Set 14 | shache
# Processing Record 19 of Set 14 | rio grande
# Processing Record 20 of Set 14 | chapleau
# Processing Record 21 of Set 14 | tromso
# Processing Record 22 of Set 14 | rocha
# Processing Record 23 of Set 14 | santa marta
# Processing Record 24 of Set 14 | aasiaat
# Processing Record 25 of Set 14 | schrobenhausen
# Processing Record 26 of Set 14 | tupi paulista
# Processing Record 27 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 28 of Set 14 | gweta
# Processing Record 29 of Set 14 | wana
# Processing Record 30 of Set 14 | staryy nadym
# Processing Record 31 of Set 14 | elverum
# Processing Record 32 of Set 14 | tabora
# Processing Record 33 of Set 14 | llangefni
# Processing Record 34 of Set 14 | general pico
# Processing Record 35 of Set 14 | bandrele
# Processing Record 36 of Set 14 | katsiveli
# City not found. Skipping...
# Processing Record 37 of Set 14 | hajipur
# Processing Record 38 of Set 14 | bud
# Processing Record 39 of Set 14 | shchelyayur
# City not found. Skipping...
# Processing Record 40 of Set 14 | acarau
# Processing Record 41 of Set 14 | cadiz
# Processing Record 42 of Set 14 | himora
# City not found. Skipping...
# Processing Record 43 of Set 14 | rochester
# Processing Record 44 of Set 14 | am timan
# Processing Record 45 of Set 14 | tucuman
# Processing Record 46 of Set 14 | mayumba
# Processing Record 47 of Set 14 | havelock
# Processing Record 48 of Set 14 | dmitriyevka
# Processing Record 49 of Set 14 | caluquembe
# Processing Record 50 of Set 14 | ugoofaaru
# Processing Record 1 of Set 15 | saint-prosper
# Processing Record 2 of Set 15 | harboore
# Processing Record 3 of Set 15 | oxford
# Processing Record 4 of Set 15 | kamwenge
# Processing Record 5 of Set 15 | pervomayskaya
# Processing Record 6 of Set 15 | tocache
# Processing Record 7 of Set 15 | rolim de moura
# City not found. Skipping...
# Processing Record 8 of Set 15 | syumsi
# Processing Record 9 of Set 15 | sterlibashevo
# Processing Record 10 of Set 15 | placido de castro
# Processing Record 11 of Set 15 | zaysan
# Processing Record 12 of Set 15 | jilib
# Processing Record 13 of Set 15 | nizwa
# Processing Record 14 of Set 15 | jesup
# Processing Record 15 of Set 15 | iquitos
# Processing Record 16 of Set 15 | ikot ekpene
# Processing Record 17 of Set 15 | straumen
# Processing Record 18 of Set 15 | torbat-e jam
# Processing Record 19 of Set 15 | sao paulo de olivenca
# Processing Record 20 of Set 15 | henties bay
# Processing Record 21 of Set 15 | somvarpet
# Processing Record 22 of Set 15 | saint-paul
# Processing Record 23 of Set 15 | lexington
# Processing Record 24 of Set 15 | alto araguaia
# Processing Record 25 of Set 15 | mutsamudu
# City not found. Skipping...
# Processing Record 26 of Set 15 | kumluca
# Processing Record 27 of Set 15 | turbat
# Processing Record 28 of Set 15 | ostersund
# Processing Record 29 of Set 15 | hobyo
# Processing Record 30 of Set 15 | mahanoro
# Processing Record 31 of Set 15 | hun
# Processing Record 32 of Set 15 | san ramon
# Processing Record 33 of Set 15 | ingelheim
# City not found. Skipping...
# Processing Record 34 of Set 15 | sandwick
# Processing Record 35 of Set 15 | barberton
# Processing Record 36 of Set 15 | knurow
# Processing Record 37 of Set 15 | tunduru
# City not found. Skipping...
# Processing Record 38 of Set 15 | santiago de cao
# Processing Record 39 of Set 15 | kirovo-chepetsk
# Processing Record 40 of Set 15 | jojoima
# Processing Record 41 of Set 15 | ovalle
# Processing Record 42 of Set 15 | zhanaozen
# Processing Record 43 of Set 15 | addi ugri
# City not found. Skipping...
# Processing Record 44 of Set 15 | ornskoldsvik
# Processing Record 45 of Set 15 | mwaya
# Processing Record 46 of Set 15 | maindargi
# Processing Record 47 of Set 15 | tenenkou
# Processing Record 48 of Set 15 | rojhan
# Processing Record 49 of Set 15 | kikwit
# Processing Record 50 of Set 15 | seoni
# Processing Record 1 of Set 16 | mehamn
# Processing Record 2 of Set 16 | dalvik
# Processing Record 3 of Set 16 | miajadas
# Processing Record 4 of Set 16 | tutoia
# Processing Record 5 of Set 16 | san luis
# Processing Record 6 of Set 16 | mykhaylivka
# Processing Record 7 of Set 16 | parfino
# Processing Record 8 of Set 16 | alta floresta
# Processing Record 9 of Set 16 | zabol
# Processing Record 10 of Set 16 | coracora
# Processing Record 11 of Set 16 | iquique
# Processing Record 12 of Set 16 | beyla
# Processing Record 13 of Set 16 | kulhudhuffushi
# Processing Record 14 of Set 16 | minab
# Processing Record 15 of Set 16 | mocambique
# City not found. Skipping...
# Processing Record 16 of Set 16 | kibiti
# Processing Record 17 of Set 16 | tsiroanomandidy
# Processing Record 18 of Set 16 | shetpe
# Processing Record 19 of Set 16 | camargo
# Processing Record 20 of Set 16 | conde
# Processing Record 21 of Set 16 | areia branca
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 712

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Saldanha -33.0117   17.9442     73.45        74           0
# 1   Krasnoselkup  65.7000   82.4667     -2.74        94         100
# 2  Ponta Delgada  37.7333  -25.6667     70.52        88          75
# 3         Dingle  10.9995  122.6711     76.08        91          70
# 4     Sao Filipe  14.8961  -24.4956     78.78        69          72
# 5     Diamantino -14.4086  -56.4461    101.97        22          10
# 6        Ushuaia -54.8000  -68.3000     49.62        42          40
# 7        Qaanaaq  77.4840  -69.3632    -10.23        61           0
# 8        Ordubad  38.9059   46.0234     48.96        83          96
# 9         Jibuti  11.5000   42.5000     75.22        72          33
#
#    Wind Speed Country Current Description
# 0       11.25      ZA           clear sky
# 1        7.09      RU     overcast clouds
# 2       28.77      PT       broken clouds
# 3        6.64      PH       broken clouds
# 4       10.02      CV       broken clouds
# 5        6.58      BR           clear sky
# 6        5.75      AR    scattered clouds
# 7        8.77      GL           clear sky
# 8        8.01      AZ     overcast clouds
# 9       17.63      DJ    scattered clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_columns = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df=city_data_df[new_columns]

# Display sample data
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Saldanha      ZA -33.0117   17.9442     73.45        74           0
# 1   Krasnoselkup      RU  65.7000   82.4667     -2.74        94         100
# 2  Ponta Delgada      PT  37.7333  -25.6667     70.52        88          75
# 3         Dingle      PH  10.9995  122.6711     76.08        91          70
# 4     Sao Filipe      CV  14.8961  -24.4956     78.78        69          72
# 5     Diamantino      BR -14.4086  -56.4461    101.97        22          10
# 6        Ushuaia      AR -54.8000  -68.3000     49.62        42          40
# 7        Qaanaaq      GL  77.4840  -69.3632    -10.23        61           0
# 8        Ordubad      AZ  38.9059   46.0234     48.96        83          96
# 9         Jibuti      DJ  11.5000   42.5000     75.22        72          33
#
#    Wind Speed Current Description
# 0       11.25           clear sky
# 1        7.09     overcast clouds
# 2       28.77       broken clouds
# 3        6.64       broken clouds
# 4       10.02       broken clouds
# 5        6.58           clear sky
# 6        5.75    scattered clouds
# 7        8.77           clear sky
# 8        8.01     overcast clouds
# 9       17.63    scattered clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_file_data = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_file_data, index_label="City_ID")
